# %%
motifs= [
    '1bcf', 
    '1prw',
    '1qjg',
    '1ycr',
    '2kl8',
    '3ixt',
    '4jhw',
    '4zyp',
    '5ius',
    '5tpn',
    '5trv_long',
    '5trv_med',
    '5trv_short',
    '5wn9',
    '5yui',
    '6e6r_long',
    '6e6r_med', 
    '6e6r_short',
    '6exz_long',
    '6exz_med',
    '6exz_short',
    '7mrx_60',
    '7mrx_85',
    '7mrx_128',
]
with open('jobs0.out', 'w') as f:
    for motif in motifs:
        f.write(f'python mydesign.py -o out/tmp/onemotif_twostates_neg_EcoRIdna_0 --num_designs 100 --task onemotif_twostates_neg --motifs {motif} --ligands dna:GAATTC\n')

# %%
with open('jobs1.out', 'w') as f:
    for i in range(16):
        #f.write(f"python mydesign.py -o ./tmp/new --num_designs 100 --task onemotif_twostates_pos --motifs 1prw --ligands ligand:[Mg+2] --recycles 3 --worker_id {i} --num_workers 16\n")
        f.write(f'python mydesign.py -o ./out/hem --num_designs 100 --task twoligands --ligands ccd:HEM ccd:HEM,ccd:OXY --recycles 3 --worker_id {i} --num_workers 16 --length 50\n')

# %%
with open('jobs1.out', 'w') as f:
    for i in range(32):
        f.write(f'python mydesign.py -o ./out/hem_0_1k --strength 0 --num_designs 1000 --task twoligands --ligands ccd:HEM ccd:HEM,ccd:OXY --recycles 3 --worker_id {i} --num_workers 32 --length 50\n')
        f.write(f'python mydesign.py -o ./out/hem_1_1k --strength 1 --num_designs 1000 --task twoligands --ligands ccd:HEM ccd:HEM,ccd:OXY --recycles 3 --worker_id {i} --num_workers 32 --length 50\n')
        f.write(f'python mydesign.py -o ./out/hem_3_1k --strength 3 --num_designs 1000 --task twoligands --ligands ccd:HEM ccd:HEM,ccd:OXY --recycles 3 --worker_id {i} --num_workers 32 --length 50\n')
        # f.write(f'python mydesign.py -o ./out/hem_10 --strength 10 --num_designs 100 --task twoligands --ligands ccd:HEM ccd:HEM,ccd:OXY --recycles 3 --worker_id {i} --num_workers 16 --length 50\n')
        # f.write(f'python mydesign.py -o ./out/hem_30 --strength 30 --num_designs 100 --task twoligands --ligands ccd:HEM ccd:HEM,ccd:OXY --recycles 3 --worker_id {i} --num_workers 16 --length 50\n')

# %%
with open('jobs2.out', 'w') as f:
    for i in range(32):
        f.write(f'python mydesign.py -o ./out/oqo_ca --strength 0.5 --num_designs 1000 --task twoligands --ligands ccd:OQO ligand:[Ca+2] --recycles 3 --worker_id {i} --num_workers 32 --length 50\n')

# %%
with open('jobs2.out', 'w') as f:
    for i in range(32):
        f.write(f'python mydesign.py -o ./out/oqo_ca --strength 0.5 --num_designs 1000 --task twoligands --ligands ccd:OQO ligand:[Ca+2] --recycles 3 --worker_id {i} --num_workers 32 --length 50\n')

# %%
with open('jobs3.out', 'w') as f:
    for i in range(32):
        f.write(f'python mydesign.py -o ./out/top7_new --strength 0.5 --num_designs 1000 --task twoligands_binding --ligands protein:GYDPETGTWG,ccd:OQO ccd:OQO --recycles 3 --worker_id {i} --num_workers 32 --length 100\n')
